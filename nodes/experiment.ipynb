# %% [markdown]
# # Experiment
#
# A random experiment is described or modeled by a mathematical construct known as a probability space.
#
# so for now we are stucked here. to define sample space we need experiment definition. and to define experiment we need probability space. so for now lets keep it simple and stay here. we will get back to it in future.
