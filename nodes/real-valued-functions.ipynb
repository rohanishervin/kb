# %% [markdown]
# # Real Valued Functions
#
# It's a [function](function.ipynb) f with following properties:
#
# $$ f: I\to\mathbb{R} $$
#
# $I$: is an [interval](interval.ipynb) and a subset of [$\mathbb{R}$](real-numbers.ipynb)
