# %% [markdown]
# # Knowledge Base
#
# This site serves as a central repository for my study notes, summaries, and problem sets.
#
# ### About this Project
# This is a **personal, non-commercial self-study project**. All explanations, proofs, and solutions are written in my own words and reflect my own understanding developed while working through the referenced texts below. Problem statements have been **adapted** from these sources. No copyrighted material has been directly reproduced. This site is not affiliated with or endorsed by any of the referenced authors or publishers.
#
# ---
#
# ### Core References
# The notebooks in this library are primarily based on the following texts:
#
# * *Principles of Mathematical Analysis* – Walter Rudin
# * *Real Mathematical Analysis* – Charles C. Pugh
# * *Real Analysis* (4th Ed.) – H.L. Royden & P.M. Fitzpatrick
# * *Real Analysis: A First Course* – Russell A. Gordon
# * *Introduction to Probability* – Joseph K. Blitzstein & Jessica Hwang
# * *An Introduction to Difference Equations* – Saber Elaydi
