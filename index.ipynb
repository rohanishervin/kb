# %% [markdown]
# # Knowledge Base
#
# This site serves as a central repository for my study notes, summaries, and problem sets.
#
# ### About this Project
# This is a **personal, non-commercial self-study project**. The content here reflects my own understanding and solutions developed while working through various mathematical texts. It is hosted publicly for ease of access across my devices and as a record of my learning progress.
#
# ---
#
# ### Core References
# The notebooks in this library are primarily based on the following texts:
#
# * *Principels of  Mathematical Analysis* – Walter Rudin
# * *Real Mathematical Analysis* – Charles C. Pugh
# * *Real Analysis* (4th Ed.) – H.L. Royden & P.M. Fitzpatrick
# * *Real Analysis: A First Course* – Russell A. Gordon
# * *Introduction to Probability* – Joseph K. Blitzstein & Jessica Hwang
