# %% [markdown]
# # TODO:
#
# 1. [ ] Fix the relation between experiment and outcome
# 2. [ ] Fix rational numbers
# 3. [ ] Bose-Einstein as solution to integer equation

# %% [markdown]
# # Prompt:
#
# you are a math knowledge base editor. it is all wrtten in markdown format in jupyter notebooks. you need to check these:
# 1. any grammatical issue in writing
# 2. any proof errors
# 3. any connection error
# 4. convert the graph to 3d so it's more usable.
# 5. make quarto.yml file auto update. by creating devlop script for local develop and deploy for github
