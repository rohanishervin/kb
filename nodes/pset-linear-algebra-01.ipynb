# %% [markdown]
# ---
# date: "2026-09-17"
# date-modified: last-modified
# format:
#   html:
#     toc: true
# ---

# %% [markdown]
# # Problem Set: Linear Algebra

# %% [markdown]
# ## Problem 1: Consequences of Axioms & Isomorphism
#
# **Problem Statement:**
#
# **(a)** Using strictly the abelian group axioms for $(E, +)$ and the scalar multiplication axioms of a [vector space](vector-spaces.ipynb) over a [field](field.ipynb) $K$, prove:
#
# 1. $0_K \cdot v = 0_E$ for all $v \in E$.
# 2. $(-1_K) \cdot v = -v$ for all $v \in E$.
# 3. For $c \in K$ and $v \in E$, $c \cdot v = 0_E \implies c = 0_K$ or $v = 0_E$.
#
# **(b)** Let $X = \{x_1, \dots, x_n\}$ be a finite set. Show that $K^X = \{f \mid f: X \to K\}$ is isomorphic to $K^n$.
#
# ::: {.callout-tip collapse="true"}
# ## Solution
#
# **(a)**
#
# 1. In $K$, $0_K + 0_K = 0_K$. By distributivity of vectors over scalar addition:
#    $$
#    0_K \cdot v = (0_K + 0_K) \cdot v = 0_K \cdot v + 0_K \cdot v
#    $$
#    Adding the additive inverse $-(0_K \cdot v) \in E$ to both sides yields:
#    $$
#    0_E = 0_K \cdot v
#    $$
#
# 2. By scalar distributivity and the scalar identity axiom $1_K \cdot v = v$:
#    $$
#    v + (-1_K) \cdot v = 1_K \cdot v + (-1_K) \cdot v = (1_K + (-1_K)) \cdot v = 0_K \cdot v = 0_E
#    $$
#    Since the additive inverse in an abelian group is unique, $(-1_K) \cdot v = -v$.
#
# 3. Suppose $c \cdot v = 0_E$. If $c = 0_K$, the conclusion holds. If $c \ne 0_K$, since $K$ is a field, there exists $c^{-1} \in K$ such that $c^{-1} c = 1_K$. Multiplying both sides by $c^{-1}$:
#    $$
#    v = 1_K \cdot v = (c^{-1} c) \cdot v = c^{-1} \cdot (c \cdot v) = c^{-1} \cdot 0_E = 0_E
#    $$
#    Hence $c = 0_K$ or $v = 0_E$.
#
# **(b)**
#
# Define the map $T: K^X \to K^n$ by $T(f) = (f(x_1), \dots, f(x_n))$.
#
# - **Linearity:** For $f, g \in K^X$ and $\alpha, \beta \in K$:
#   $$
#   T(\alpha f + \beta g) = ((\alpha f + \beta g)(x_1), \dots, (\alpha f + \beta g)(x_n)) = \alpha T(f) + \beta T(g)
#   $$
# - **Injectivity:** If $T(f) = (0, \dots, 0)$, then $f(x_i) = 0$ for all $i \in \{1, \dots, n\}$, which means $f \equiv 0$. Thus $\ker(T) = \{0\}$.
# - **Surjectivity:** For any tuple $(k_1, \dots, k_n) \in K^n$, the function $f \in K^X$ defined by $f(x_i) = k_i$ satisfies $T(f) = (k_1, \dots, k_n)$.
#
# Thus $T$ is a linear bijection, proving $K^X \cong K^n$.
#
# $\blacksquare$
# :::

# %% [markdown]
# ## Problem 2: Subspace Union, Intersection & Span Equivalence
#
# **Problem Statement:**
#
# **(a)** Let $E_1, E_2 \le E$ be [subspaces](vector-spaces.ipynb#def-subspace). Show that $E_1 \cup E_2 \le E \iff E_1 \subseteq E_2$ or $E_2 \subseteq E_1$.
#
# **(b)** Show that the intersection $\bigcap_{i \in I} E_i$ of an arbitrary family of subspaces is a subspace.
#
# **(c)** For $S \subseteq E$, prove that $\text{Span}(S) = \bigcap \{U \le E \mid S \subseteq U\}$.
#
# ::: {.callout-tip collapse="true"}
# ## Solution
#
# **(a)**
#
# - $(\Leftarrow)$ If $E_1 \subseteq E_2$, then $E_1 \cup E_2 = E_2 \le E$. Symmetrically, if $E_2 \subseteq E_1$, then $E_1 \cup E_2 = E_1 \le E$.
# - $(\Rightarrow)$ Assume for contradiction that $E_1 \cup E_2 \le E$, but $E_1 \not\subseteq E_2$ and $E_2 \not\subseteq E_1$. Then there exist $u \in E_1 \setminus E_2$ and $v \in E_2 \setminus E_1$. Since $E_1 \cup E_2$ is a subspace, $u + v \in E_1 \cup E_2$:
#   - If $u + v \in E_1$, then $v = (u + v) - u \in E_1$, a contradiction.
#   - If $u + v \in E_2$, then $u = (u + v) - v \in E_2$, a contradiction.
#
# Hence $E_1 \subseteq E_2$ or $E_2 \subseteq E_1$.
#
# **(b)**
#
# Let $F = \bigcap_{i \in I} E_i$.
#
# - Since each $E_i$ is a subspace, $0_E \in E_i$ for all $i \in I$, so $0_E \in F \ne \emptyset$.
# - For $u, v \in F$ and $c \in K$, since each $E_i$ is a subspace, $cu + v \in E_i$ for every $i \in I$. Hence $cu + v \in F$.
#
# Thus $F$ is a subspace of $E$.
#
# **(c)**
#
# Let $U_{\min} = \bigcap \{U \le E \mid S \subseteq U\}$ and $L(S) = \left\{ \sum_{i=1}^m \alpha_i v_i \;\middle|\; m \in \mathbb{N}, \alpha_i \in K, v_i \in S \right\}$.
#
# 1. **$L(S) \subseteq U_{\min}$:** Any subspace $U$ containing $S$ contains all finite linear combinations of vectors in $S$. Thus $L(S) \subseteq U$ for all such $U$, implying $L(S) \subseteq U_{\min}$.
# 2. **$U_{\min} \subseteq L(S)$:** $L(S)$ is itself a subspace containing $S$ (since for any $s \in S$, $s = 1_K \cdot s \in L(S)$). Therefore $L(S)$ is one of the subspaces being intersected, which implies $U_{\min} \subseteq L(S)$.
#
# Hence $\text{Span}(S) = L(S) = U_{\min}$.
#
# $\blacksquare$
# :::

# %% [markdown]
# ## Problem 3: First-Dependent Vector Lemma
#
# **Problem Statement:**
#
# Let $v_1, \dots, v_m \in E$ with $m \ge 2$. Prove that $\{v_1, \dots, v_m\}$ is [linearly dependent](linear-independence-basis-dimension.ipynb) if and only if $v_1 = 0_E$ or there exists some index $j \in \{2, \dots, m\}$ such that $v_j \in \text{Span}(v_1, \dots, v_{j-1})$.
#
# ::: {.callout-tip collapse="true"}
# ## Solution
#
# **$(\Leftarrow)$:**
#
# - If $v_1 = 0_E$, then $1_K v_1 + 0 v_2 + \dots + 0 v_m = 0_E$ is a non-trivial linear combination.
# - If $v_j \in \text{Span}(v_1, \dots, v_{j-1})$ for some $j \in \{2, \dots, m\}$, then $v_j = \sum_{i=1}^{j-1} c_i v_i$, so:
#   $$
#   c_1 v_1 + \dots + c_{j-1} v_{j-1} - 1_K v_j + 0 v_{j+1} + \dots + 0 v_m = 0_E
#   $$
#   Since the coefficient of $v_j$ is $-1_K \ne 0_K$, this is a non-trivial vanishing combination.
#
# In both cases, $\{v_1, \dots, v_m\}$ is linearly dependent.
#
# **$(\Rightarrow)$:**
#
# Suppose $\sum_{i=1}^m \alpha_i v_i = 0_E$ with at least one non-zero coefficient. Choose the maximal non-zero index:
# $$
# j = \max \{i \in \{1, \dots, m\} \mid \alpha_i \ne 0_K\}
# $$
#
# - If $j = 1$, then $\alpha_1 v_1 = 0_E$ with $\alpha_1 \ne 0_K \implies v_1 = 0_E$.
# - If $j \ge 2$, then $\alpha_1 v_1 + \dots + \alpha_j v_j = 0_E$ (since $\alpha_i = 0_K$ for all $i > j$). Multiplying by $\alpha_j^{-1}$:
#   $$
#   v_j = \sum_{i=1}^{j-1} \left( -\frac{\alpha_i}{\alpha_j} \right) v_i \in \text{Span}(v_1, \dots, v_{j-1})
#   $$
#
# $\blacksquare$
# :::

# %% [markdown]
# ## Problem 4: Single Exchange Step of Steinitz
#
# **Problem Statement:**
#
# Let $E = \text{Span}(w_1, \dots, w_n)$ and let $v \in E$ be a non-zero vector expressed as $v = \sum_{i=1}^n \alpha_i w_i$. If $\alpha_k \ne 0_K$, prove that:
# $$
# \text{Span}(w_1, \dots, w_{k-1}, v, w_{k+1}, \dots, w_n) = E
# $$
#
# ::: {.callout-tip collapse="true"}
# ## Solution
#
# Let $S' = \{w_1, \dots, w_{k-1}, v, w_{k+1}, \dots, w_n\}$. Since $S' \subseteq E$ and $E$ is a subspace, $\text{Span}(S') \subseteq E$.
#
# For the reverse inclusion, solve for $w_k$ using $\alpha_k \ne 0_K$:
# $$
# v = \alpha_k w_k + \sum_{i \ne k} \alpha_i w_i \implies w_k = \frac{1}{\alpha_k} v - \sum_{i \ne k} \frac{\alpha_i}{\alpha_k} w_i
# $$
#
# Since $v \in S'$ and $w_i \in S'$ for all $i \ne k$, we have $w_k \in \text{Span}(S')$. Therefore, the original generating set satisfies $\{w_1, \dots, w_n\} \subseteq \text{Span}(S')$, which implies:
# $$
# E = \text{Span}(w_1, \dots, w_n) \subseteq \text{Span}(S')
# $$
#
# Hence $\text{Span}(S') = E$.
#
# $\blacksquare$
# :::

# %% [markdown]
# ## Problem 5: Basis of Subspace Sum $U + W$
#
# **Problem Statement:**
#
# Let $U, W \le E$ be finite-dimensional subspaces. Let $\{v_1, \dots, v_m\}$ be a [basis](linear-independence-basis-dimension.ipynb) of $U \cap W$, extended to a basis $\{v_1, \dots, v_m, u_1, \dots, u_r\}$ of $U$, and to a basis $\{v_1, \dots, v_m, w_1, \dots, w_s\}$ of $W$. Prove that:
# $$
# \mathcal{B} = \{v_1, \dots, v_m, u_1, \dots, u_r, w_1, \dots, w_s\}
# $$
# is a basis of the [subspace sum](linear-independence-basis-dimension.ipynb#def-sum-subspaces) $U + W$.
#
# ::: {.callout-tip collapse="true"}
# ## Solution
#
# **1. Spanning:**
#
# Any $x \in U + W$ can be written as $x = u + w$ with $u \in U$ and $w \in W$. Expanding $u$ in the basis of $U$ and $w$ in the basis of $W$ yields:
# $$
# x = \sum_{i=1}^m (a_i + a'_i) v_i + \sum_{j=1}^r b_j u_j + \sum_{k=1}^s c_k w_k \in \text{Span}(\mathcal{B})
# $$
# Thus $\text{Span}(\mathcal{B}) = U + W$.
#
# **2. Linear Independence:**
#
# Suppose:
# $$
# \sum_{i=1}^m \alpha_i v_i + \sum_{j=1}^r \beta_j u_j + \sum_{k=1}^s \gamma_k w_k = 0_E
# $$
#
# Rearranging terms:
# $$
# \underbrace{\sum_{k=1}^s \gamma_k w_k}_{\in W} = - \underbrace{\left( \sum_{i=1}^m \alpha_i v_i + \sum_{j=1}^r \beta_j u_j \right)}_{\in U}
# $$
#
# This shows the vector $y = \sum_{k=1}^s \gamma_k w_k$ belongs to both $W$ and $U$, so $y \in U \cap W$. Because $\{v_1, \dots, v_m\}$ is a basis of $U \cap W$, there exist scalars $\delta_i$ such that:
# $$
# \sum_{k=1}^s \gamma_k w_k = \sum_{i=1}^m \delta_i v_i \implies \sum_{i=1}^m \delta_i v_i - \sum_{k=1}^s \gamma_k w_k = 0_E
# $$
#
# Since $\{v_1, \dots, v_m, w_1, \dots, w_s\}$ is a basis of $W$, its vectors are linearly independent, so:
# $$
# \gamma_1 = \dots = \gamma_s = 0_K
# $$
#
# Substituting these back into the original equation leaves:
# $$
# \sum_{i=1}^m \alpha_i v_i + \sum_{j=1}^r \beta_j u_j = 0_E
# $$
#
# Since $\{v_1, \dots, v_m, u_1, \dots, u_r\}$ is a basis of $U$, linear independence implies $\alpha_1 = \dots = \alpha_m = 0_K$ and $\beta_1 = \dots = \beta_r = 0_K$. Thus all coefficients are zero, and $\mathcal{B}$ is linearly independent.
#
# Therefore, $\mathcal{B}$ is a basis of $U + W$.
#
# $\blacksquare$
# :::

# %% [markdown]
# ## Problem 6: Uniqueness of Coordinate Representation
#
# **Problem Statement:**
#
# Let $E$ be an $n$-dimensional [vector space](vector-spaces.ipynb) over $K$ with an ordered [basis](linear-independence-basis-dimension.ipynb) $\mathcal{B} = (v_1, \dots, v_n)$. Prove that every vector $u \in E$ has a unique representation $u = \sum_{i=1}^n \alpha_i v_i$ with $\alpha_i \in K$.
#
# ::: {.callout-tip collapse="true"}
# ## Solution
#
# - **Existence:** Since $\mathcal{B}$ is a basis, it spans $E$. Therefore at least one representation exists for every $u \in E$.
# - **Uniqueness:** Suppose there exists another representation $u = \sum_{i=1}^n \alpha'_i v_i$. Subtracting the two gives:
#   $$
#   0_E = u - u = \sum_{i=1}^n (\alpha_i - \alpha'_i) v_i
#   $$
#   Because $\mathcal{B}$ is a basis, the vectors $v_1, \dots, v_n$ are linearly independent. Hence the vanishing linear combination has only the trivial solution:
#   $$
#   \alpha_i - \alpha'_i = 0_K \implies \alpha_i = \alpha'_i \quad \forall i \in \{1, \dots, n\}
#   $$
#
# Thus the coordinate tuple $(\alpha_1, \dots, \alpha_n) \in K^n$ is unique.
#
# $\blacksquare$
# :::
