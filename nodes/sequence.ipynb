# %% [markdown]
# # Sequence
#
# A sequence is a [function](function.ipynb) whose domain is positive integers. a sequence of real nubmers is a sequence whose codomain is [$\mathbb{R}$](real-numbers.ipynb).
