# %% [markdown]
# # Squeeze Theorem for Sequences
#
# if for [sequences](sequence.ipynb) $a_n, b_n, c_n$ we have $\{a_n\} \leq \{b_n\} \leq \{c_n\}$ and $\{a_n\}, \{c_n\}$ both converges to $L$. $\{b_n\}$ also converges to $L$.
